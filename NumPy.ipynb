# %%
import numpy as np

# %%
#1次元配列
a = np.array([1, 2, 3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b = np.array([[1, 2, 3],[4, 5, 6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c1 = np.array([0, 1, 2, 3, 4, 5])
c1
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
#変形（reshape)
#↓の場合は2行、３列の２次元配列に変換する
c2 = c1.reshape((2 , 3))
c2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
#変換（ravel)
c3 = c2.ravel()
c3
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
#copyを返す
c4 = c2.flatten()
c4
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
d = np.array([1, 2], dtype=np.int16)#np.int16の型宣言
d
# Out:
# array([1, 2], dtype=int16)

# %%
d.dtype
# Out:
# dtype('int16')

# %%
#astypeメソッドで型変換する
d.astype(np.float16)
# Out:
# array([1., 2.], dtype=float16)

# %%
a
# Out:
# array([1, 2, 3])

# %%
a[0]#先頭データの取得
# Out:
# np.int64(1)

# %%
a[1:]#スライス １番目～
# Out:
# array([2, 3])

# %%
a[-1]#末尾から数える
# Out:
# np.int64(3)

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
