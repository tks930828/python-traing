# %%
import numpy as np
a = np.array([1, 2, 3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (3,)

# %%
b = np.array([[1, 2, 3], [4, 5, 6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b.shape
# Out:
# (2, 3)

# %%
c1 = np.array([0, 1, 2, 3, 4, 5])
c1
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
c2 = c1.reshape((2 ,3))
c2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
c3 = c2.ravel()
c3
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
c4 = c2.flatten() #コピーを返す
c4
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
d = np.array([1, 2], dtype=np.int16)
d
# Out:
# array([1, 2], dtype=int16)

# %%
d.dtype
# Out:
# dtype('int16')
