# %%
import numpy as np

# %%
c1 = np.array([0, 1, 2, 3, 4, 5])
c1
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
#変形（reshape)
#↓の場合は2行、３列の２次元配列に変換する
c2 = c1.reshape((2 , 3))
c2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
c3 = c2.ravel()
c3
# Out:
# array([0, 1, 2, 3, 4, 5])
